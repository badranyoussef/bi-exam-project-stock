# %% [markdown]
# # Sprint 2: Data Preparation
#
# ### Loading data from CSV file

# %%
# import og nesecery libraries

import pandas as pd
import os

# %%
#youssef_path = '/Users/youssefbadran/Documents/datamatiker/4. semester/BI/sp500_data.csv'


#df_sp500 = pd.read_csv('/Users/youssefbadran/Documents/datamatiker/4. semester/BI/sp500_data.csv')
df_interest_inflation = pd.read_csv('https://raw.githubusercontent.com/badranyoussef/bi-exam-project-stock/main/datasets/fed_interest_rate_inflation.csv')

# Reading from split csv files
# define arr with csv file names from directory
dir = 'https://github.com/badranyoussef/bi-exam-project-stock/tree/main/datasets/sp500'
csv_files = [f for f in os.listdir(dir) if f.endswith('.csv')]

# load all csv-files into a data frame
dfs = [pd.read_csv(os.path.join(dir, file)) for file in csv_files]

# combine all DFs in one
df_sp500 = pd.concat(dfs, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 5
#       1 #youssef_path = '/Users/youssefbadran/Documents/datamatiker/4. semester/BI/sp500_data.csv'
#       2
#       3
#       4 #df_sp500 = pd.read_csv('/Users/youssefbadran/Documents/datamatiker/4. semester/BI/sp500_data.csv')
# ----> 5 df_interest_inflation = pd.read_csv('/datasets/fed_interest_rate_inflation.csv')
#       7 # Reading from split csv files
#       8 # define arr with csv file names from directory
#       9 csv_files = [f for f in os.listdir('datasets/sp500') if f.endswith('.csv')]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/datasets/fed_interest_rate_inflation.csv'

# %% [markdown]
# ### Cleaning SP500 DF

# %%
df_sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4239723 entries, 0 to 4239722
# Data columns (total 8 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Date       object
#  1   Open       float64
#  2   High       float64
#  3   Low        float64
#  4   Close      float64
#  5   Adj Close  float64
#  6   Volume     float64
#  7   Ticker     object
# dtypes: float64(6), object(2)
# memory usage: 258.8+ MB

# %%
df_sp500.head()
# Out:
#          Date  Open      High       Low     Close  Adj Close    Volume Ticker
# 0  1962-01-02   0.0  3.553512  3.448997  3.475125   0.570977  254509.0    MMM
# 1  1962-01-03   0.0  3.501254  3.416336  3.501254   0.575270  505190.0    MMM
# 2  1962-01-04   0.0  3.560044  3.501254  3.501254   0.575270  254509.0    MMM
# 3  1962-01-05   0.0  3.488190  3.396739  3.409804   0.560244  376979.0    MMM
# 4  1962-01-08   0.0  3.416336  3.370610  3.390207   0.557025  399942.0    MMM

# %%
df_sp500 = df_sp500.drop(columns="Ticker")

# %%
df_sp500.head()
# Out:
#          Date  Open      High       Low     Close  Adj Close    Volume
# 0  1962-01-02   0.0  3.553512  3.448997  3.475125   0.570977  254509.0
# 1  1962-01-03   0.0  3.501254  3.416336  3.501254   0.575270  505190.0
# 2  1962-01-04   0.0  3.560044  3.501254  3.501254   0.575270  254509.0
# 3  1962-01-05   0.0  3.488190  3.396739  3.409804   0.560244  376979.0
# 4  1962-01-08   0.0  3.416336  3.370610  3.390207   0.557025  399942.0

# %%
df_sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4239723 entries, 0 to 4239722
# Data columns (total 7 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Date       object
#  1   Open       float64
#  2   High       float64
#  3   Low        float64
#  4   Close      float64
#  5   Adj Close  float64
#  6   Volume     float64
# dtypes: float64(6), object(1)
# memory usage: 226.4+ MB

# %%
# Checking for null values
print(df_sp500.isnull().sum())
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ### Cleaning interest and inflation DF

# %%
df_interest_inflation.sample(15)
# Out:
#      Year  Month  Day  Federal Funds Target Rate  Federal Funds Upper Target  \
# 518  1991      2    1                     6.2500                         NaN
# 193  1970      8    1                        NaN                         NaN
# 745  2005      8    9                     3.5000                         NaN
# 884  2015     11    1                        NaN                        0.25
# 349  1983      3   31                     8.6250                         NaN
# 443  1987      8   27                     6.7500                         NaN
# 233  1973     12    1                        NaN                         NaN
# 553  1993      2    1                     3.0000                         NaN
# 293  1978     12    1                        NaN                         NaN
# 585  1995      4    1                     6.0000                         NaN
# 308  1980      3    1                        NaN                         NaN
# 862  2014      1    1                        NaN                        0.25
# 669  2001      1   31                     5.5000                         NaN
# 345  1982     12   14                     8.5000                         NaN
# 417  1986      4    2                     7.3125                         NaN
#
#      Federal Funds Lower Target  Effective Federal Funds Rate  \
# 518                         NaN                          6.25
# 193                         NaN                          6.61
# 745                         NaN                           NaN
# 884                         0.0                          0.12
# 349                         NaN                           NaN
# 443                         NaN                           NaN
# 233                         NaN                          9.95
# 553                         NaN                          3.03
# 293                         NaN                         10.03
# 585                         NaN                          6.05
# 308                         NaN                         17.19
# 862                         0.0                          0.07
# 669                         NaN                           NaN
# 345                         NaN                           NaN
# 417                         NaN                           NaN
#
#      Real GDP (Percent Change)  Unemployment Rate  Inflation Rate
# 518                        NaN                6.6             5.6
# 193                        NaN                5.1             6.2
# 745                        NaN                NaN             NaN
# 884                        NaN                5.0             2.0
# 349                        NaN                NaN             NaN
# 443                        NaN                NaN             NaN
# 233                        NaN                4.9             4.7
# 553                        NaN                7.1             3.6
# 293                        NaN                6.0             8.5
# 585                        1.4                5.8             3.1
# 308                        NaN                6.3            12.5
# 862                       -1.2                6.6             1.6
# 669                        NaN                NaN             NaN
# 345                        NaN                NaN             NaN
# 417                        NaN                NaN             NaN

# %%
df_interest_inflation_dropped = df_interest_inflation.drop([0])

df_interest_inflation.head()
# Out:
#    Year  Month  Day  Effective Federal Funds Rate  Inflation Rate
# 0  1954      7    1                          0.80             NaN
# 1  1954      8    1                          1.22             NaN
# 2  1954      9    1                          1.06             NaN
# 3  1954     10    1                          0.85             NaN
# 4  1954     11    1                          0.83             NaN

# %%
df_interest_inflation.head()
# Out:
#    Year  Month  Day  Effective Federal Funds Rate  Inflation Rate
# 0  1954      7    1                          0.80             NaN
# 1  1954      8    1                          1.22             NaN
# 2  1954      9    1                          1.06             NaN
# 3  1954     10    1                          0.85             NaN
# 4  1954     11    1                          0.83             NaN

# %% [markdown]
# ### Data seams to be pretty clean and ready to use. There are no null or missing values. I only dropped on column called Ticker which has no influence in our project
